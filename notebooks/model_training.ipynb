# %% [markdown]
# # Gem Price Prediction System for Ratnapura, Sri Lanka

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
import joblib

# %%
dataSetOne = pd.read_csv('data/nish_catalog_run.csv')
dataSetTwo = pd.read_csv('data/jngems_custom_ignore.csv')

print("data Set One:", dataSetOne.shape)
print("data Set Two :", dataSetTwo.shape)
# Out:
# data Set One: (50, 20)
# data Set Two : (264, 30)

# %%
a = pd.read_csv('data/Gem Data Set - Sellers_Data.csv')
b = pd.read_csv('data/seller-a/yellow-sapphire_scrate_gems.csv')


columns_are_identical_strict = list(a.columns) == list(b.columns)
print(f"Are df1 and df2 columns identical (strict)? {columns_are_identical_strict}")
# Out:
# Are df1 and df2 columns identical (strict)? False
